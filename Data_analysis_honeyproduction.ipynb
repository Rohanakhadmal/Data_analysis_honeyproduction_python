# %% [markdown]
# # 1. Import required libraries and read the dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\rohan\OneDrive\Documents\HomeWork_GL\Python\Python Project 04 - Graded Project\honeyproduction.csv")

df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# # 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
print("First few samples are as follows :")

df.head()
# Out:
# First few samples are as follows :
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
print("Shape of data is :")

df.shape
# Out:
# Shape of data is :
# (626, 8)

# %%
print("Information of data is :")

df.info()
# Out:
# Information of data is :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %% [markdown]
# # 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
# So we have to distribute the data by 'year' and calculate the the percentage

yearly_dist = (df['year'].value_counts(normalize = True) * 100)
yearly_dist
# Out:
# year
# 2001    7.028754
# 2002    7.028754
# 2003    7.028754
# 1998    6.869010
# 1999    6.869010
# 2000    6.869010
# 2004    6.549521
# 2005    6.549521
# 2006    6.549521
# 2007    6.549521
# 2008    6.549521
# 2009    6.389776
# 2010    6.389776
# 2011    6.389776
# 2012    6.389776
# Name: proportion, dtype: float64

# %%
# Now we have to create a peichart

plt.figure(figsize=(5, 6))
plt.pie(yearly_dist, labels=yearly_dist.index, autopct='%1.1f%%', startangle=140)
plt.title('Percentage Distribution of Data by Year')
plt.axis('equal')
plt.show()

# %% [markdown]
# # 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
# So now w have to plot the distribution of the variable "price per lb"

plt.figure(figsize=(8, 5))
sns.histplot(df['priceperlb'], kde=True, bins=20, color='grey')
plt.title('Distribution of Price per lb')
plt.xlabel('Price per lb')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# # 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
# So now we have to plot scatterploy to under the relationship between the variables 'numcol' and 'prodvalue'

plt.figure(figsize = (8, 5))
sns.scatterplot(x = df.numcol, y = df.prodvalue, color = "blue")
plt.title("Relatiobship between the variables 'numcol' and 'prodvalue'")
plt.xlabel("Number of colonies")
plt.ylabel("Number of Value")
plt.grid(True)
plt.show()

# %% [markdown]
# # 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
# Plotting a boxplot to see the relationship between categorical variable 'year' and a numerical variable 'prodvalue'

plt.figure(figsize=(10, 5))
sns.boxplot(x= df.year, y=df.prodvalue)
plt.title('Relationship between Year and Production Value')
plt.xlabel('Year')
plt.ylabel('Production Value')
plt.grid(True)
plt.show()

# %% [markdown]
# # 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
# Now we have to select relevant column for our pairplot

col_of_interest = ['numcol', 'yieldpercol', 'totalprod', 'prodvalue', 'year']
data_subset = df[col_of_interest]
data_subset.head(10)
# Out:
#      numcol  yieldpercol   totalprod   prodvalue  year
# 0   16000.0           71   1136000.0    818000.0  1998
# 1   55000.0           60   3300000.0   2112000.0  1998
# 2   53000.0           65   3445000.0   2033000.0  1998
# 3  450000.0           83  37350000.0  23157000.0  1998
# 4   27000.0           72   1944000.0   1361000.0  1998
# 5  230000.0           98  22540000.0  14426000.0  1998
# 6   75000.0           56   4200000.0   2898000.0  1998
# 7    8000.0          118    944000.0    727000.0  1998
# 8  120000.0           50   6000000.0   3900000.0  1998
# 9    9000.0           71    639000.0    760000.0  1998

# %%
# Now we have to plotting by pairplot

sns.pairplot(data_subset, hue='year', palette='Set1', diag_kind='kde')
plt.suptitle('Pairplot of Variables by Year', y=1.02)
plt.show()
# Out:
# C:\Users\rohan\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
col_interest = ['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']
data_subset = df[col_interest]
data_subset.head(10)
# Out:
#      numcol  yieldpercol   totalprod      stocks  priceperlb   prodvalue
# 0   16000.0           71   1136000.0    159000.0        0.72    818000.0
# 1   55000.0           60   3300000.0   1485000.0        0.64   2112000.0
# 2   53000.0           65   3445000.0   1688000.0        0.59   2033000.0
# 3  450000.0           83  37350000.0  12326000.0        0.62  23157000.0
# 4   27000.0           72   1944000.0   1594000.0        0.70   1361000.0
# 5  230000.0           98  22540000.0   4508000.0        0.64  14426000.0
# 6   75000.0           56   4200000.0    307000.0        0.69   2898000.0
# 7    8000.0          118    944000.0     66000.0        0.77    727000.0
# 8  120000.0           50   6000000.0   2220000.0        0.65   3900000.0
# 9    9000.0           71    639000.0    204000.0        1.19    760000.0

# %%
# Now we have to compute the correlation matrix

corr_matrix = data_subset.corr()
corr_matrix
# Out:
#                numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue
# numcol       1.000000     0.243515   0.953594  0.825929   -0.232701   0.912796
# yieldpercol  0.243515     1.000000   0.396252  0.367812   -0.358646   0.278977
# totalprod    0.953594     0.396252   1.000000  0.878830   -0.264499   0.907236
# stocks       0.825929     0.367812   0.878830  1.000000   -0.305867   0.728560
# priceperlb  -0.232701    -0.358646  -0.264499 -0.305867    1.000000  -0.089567
# prodvalue    0.912796     0.278977   0.907236  0.728560   -0.089567   1.000000

# %%
# Now we have to create a heatmap to visualize the correlation matrix

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Selected Variables')
plt.show()
